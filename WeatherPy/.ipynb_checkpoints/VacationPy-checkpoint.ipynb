# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0      guarapari -20.6667  -40.4975     23.27        92         100
# 1        1         kodiak  57.7900 -152.4072     -1.27        93         100
# 2        2         albany  42.6001  -73.9662      0.78        80         100
# 3        3   puerto ayora  -0.7393  -90.3518     24.19        96          15
# 4        4  haiku-pauwela  20.9219 -156.3051     23.01        75          20
#
#    Wind Speed Country        Date
# 0        3.69      BR  2024-01-01
# 1        2.57      US  2024-01-01
# 2        0.62      US  2024-01-01
# 3        2.91      EC  2024-01-01
# 4        3.60      US  2024-01-01

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
all_cities_map = city_data_df.hvplot.points("Lng", "Lat", 
                                            geo=True, 
                                            frame_width = 700, 
                                            frame_height = 500, 
                                            color="City",
                                            alpha= 0.5,
                                            s="Humidity",
                                            scale= 0.8, 
                                            tiles="OSM")

# Display the map
all_cities_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
desired_df = city_data_df.loc[(city_data_df["Max Temp"]<=30)\
                             &(city_data_df["Max Temp"]>=19)\
                             &(city_data_df["Cloudiness"]>=30)\
                             &(city_data_df["Humidity"]<=75)\
                             &(city_data_df["Wind Speed"]>3),:]
print(len(desired_df))

# Drop any rows with null values
desired_df.dropna()

# Display sample data
desired_df
# Out:
# 29
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 9          9        oodweyne   9.4092   45.0640     21.70        24
# 38        38          avarua -21.2078 -159.7750     26.03        69
# 65        65  margaret river -33.9500  115.0667     22.26        54
# 83        83        lamarque -39.4230  -65.7021     22.16        62
# 85        85      nuku'alofa -21.1333 -175.2000     25.78        75
# 105      105     west island -12.1568   96.8225     29.99        70
# 153      153     kattivakkam  13.2167   80.3167     29.05        58
# 165      165         newnham -41.3833  147.1333     24.53        46
# 207      207       ulladulla -35.3500  150.4667     23.11        72
# 219      219   port mathurin -19.6833   63.4167     27.64        74
# 257      257            nago  26.5881  127.9761     21.24        61
# 295      295        hengchun  22.0042  120.7439     21.28        69
# 296      296          namibe -15.1961   12.1522     21.15        74
# 310      310      codrington -38.2667  141.9667     19.02        70
# 321      321        tiadiaye  14.4167  -16.7000     21.45        17
# 324      324    saint-pierre -21.3393   55.4781     28.82        70
# 332      332       port-vila -17.7338  168.3219     27.62        72
# 373      373         isangel -19.5500  169.2667     28.00        69
# 405      405     nova sintra  14.8667  -24.7167     22.63        59
# 427      427          pandan  14.0453  124.1694     28.48        72
# 442      442   mount gambier -37.8333  140.7667     19.28        66
# 448      448         mandera   3.9366   41.8670     28.01        45
# 460      460        chetwayi  10.5333   76.0500     28.95        55
# 465      465         le port -20.9373   55.2919     29.00        74
# 468      468          sydney -33.8679  151.2073     24.09        73
# 479      479         pathein  16.7833   94.7333     28.68        41
# 528      528           tokar  18.4254   37.7290     23.86        61
# 571      571        lakatoro -16.0999  167.4164     29.05        74
# 600      600         yeppoon -23.1333  150.7333     28.88        65
#
#      Cloudiness  Wind Speed Country        Date
# 9            39        4.03      SO  2024-01-01
# 38           87        3.60      CK  2024-01-01
# 65          100        7.84      AU  2024-01-01
# 83          100        5.25      AR  2024-01-01
# 85           34        9.01      TO  2024-01-01
# 105          40        5.14      CC  2024-01-01
# 153          81        5.24      IN  2024-01-01
# 165          40        6.17      AU  2024-01-01
# 207          86        6.00      AU  2024-01-01
# 219          71        3.60      MU  2024-01-01
# 257          72        4.63      JP  2024-01-01
# 295          96       11.86      TW  2024-01-01
# 296          66        3.80      AO  2024-01-01
# 310         100        7.06      AU  2024-01-01
# 321          88        3.82      SN  2024-01-01
# 324          73        4.63      RE  2024-01-01
# 332          72        6.51      VU  2024-01-01
# 373          77        6.09      VU  2024-01-01
# 405         100        4.35      CV  2024-01-01
# 427          50        3.94      PH  2024-01-01
# 442         100        5.93      AU  2024-01-01
# 448          82        3.95      KE  2024-01-01
# 460          56        5.62      IN  2024-01-01
# 465          91        3.67      RE  2024-01-01
# 468          75        7.72      AU  2024-01-01
# 479          83        3.26      MM  2024-01-01
# 528          47        4.45      SD  2024-01-01
# 571          98        4.87      VU  2024-01-01
# 600          73        5.46      AU  2024-01-01

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = desired_df.iloc[:,[1,8,2,3,5]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=""

# Display sample data
hotel_df
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 9          oodweyne      SO   9.4092   45.0640        24
# 38           avarua      CK -21.2078 -159.7750        69
# 65   margaret river      AU -33.9500  115.0667        54
# 83         lamarque      AR -39.4230  -65.7021        62
# 85       nuku'alofa      TO -21.1333 -175.2000        75
# 105     west island      CC -12.1568   96.8225        70
# 153     kattivakkam      IN  13.2167   80.3167        58
# 165         newnham      AU -41.3833  147.1333        46
# 207       ulladulla      AU -35.3500  150.4667        72
# 219   port mathurin      MU -19.6833   63.4167        74
# 257            nago      JP  26.5881  127.9761        61
# 295        hengchun      TW  22.0042  120.7439        69
# 296          namibe      AO -15.1961   12.1522        74
# 310      codrington      AU -38.2667  141.9667        70
# 321        tiadiaye      SN  14.4167  -16.7000        17
# 324    saint-pierre      RE -21.3393   55.4781        70
# 332       port-vila      VU -17.7338  168.3219        72
# 373         isangel      VU -19.5500  169.2667        69
# 405     nova sintra      CV  14.8667  -24.7167        59
# 427          pandan      PH  14.0453  124.1694        72
# 442   mount gambier      AU -37.8333  140.7667        66
# 448         mandera      KE   3.9366   41.8670        45
# 460        chetwayi      IN  10.5333   76.0500        55
# 465         le port      RE -20.9373   55.2919        74
# 468          sydney      AU -33.8679  151.2073        73
# 479         pathein      MM  16.7833   94.7333        41
# 528           tokar      SD  18.4254   37.7290        61
# 571        lakatoro      VU -16.0999  167.4164        74
# 600         yeppoon      AU -23.1333  150.7333        65

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories":"accommodation.hotel",\
          "apiKey":geoapify_key,\
          "limit":1}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lon = row["Lng"]
    lat = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# oodweyne - nearest hotel: فندق المدينه
# avarua - nearest hotel: Paradise Inn
# margaret river - nearest hotel: Margaret River Hotel
# lamarque - nearest hotel: No hotel found
# nuku'alofa - nearest hotel: City Hotel
# west island - nearest hotel: Cocos Village Bungalows
# kattivakkam - nearest hotel: No hotel found
# newnham - nearest hotel: Riverside Hotel Motel
# ulladulla - nearest hotel: Hotel Marlin
# port mathurin - nearest hotel: Escale Vacances
# nago - nearest hotel: グリーンリッチホテル
# hengchun - nearest hotel: 海的顏色精品旅館
# namibe - nearest hotel: Hotel Chik Chik Namibe
# codrington - nearest hotel: No hotel found
# tiadiaye - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropic Hotel
# port-vila - nearest hotel: Holiday Inn Resort Vanuatu
# isangel - nearest hotel: Tanna Lodge
# nova sintra - nearest hotel: Residência Ka Dencho
# pandan - nearest hotel: No hotel found
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# mandera - nearest hotel: Kornesh Hotel and Lodging
# chetwayi - nearest hotel: ever green
# le port - nearest hotel: No hotel found
# sydney - nearest hotel: The Fullerton Hotel
# pathein - nearest hotel: Taan Taan Ta
# tokar - nearest hotel: No hotel found
# lakatoro - nearest hotel: No hotel found
# yeppoon - nearest hotel: Blossom's on Seaspray
#                City Country      Lat       Lng  Humidity  \
# 9          oodweyne      SO   9.4092   45.0640        24
# 38           avarua      CK -21.2078 -159.7750        69
# 65   margaret river      AU -33.9500  115.0667        54
# 83         lamarque      AR -39.4230  -65.7021        62
# 85       nuku'alofa      TO -21.1333 -175.2000        75
# 105     west island      CC -12.1568   96.8225        70
# 153     kattivakkam      IN  13.2167   80.3167        58
# 165         newnham      AU -41.3833  147.1333        46
# 207       ulladulla      AU -35.3500  150.4667        72
# 219   port mathurin      MU -19.6833   63.4167        74
# 257            nago      JP  26.5881  127.9761        61
# 295        hengchun      TW  22.0042  120.7439        69
# 296          namibe      AO -15.1961   12.1522        74
# 310      codrington      AU -38.2667  141.9667        70
# 321        tiadiaye      SN  14.4167  -16.7000        17
# 324    saint-pierre      RE -21.3393   55.4781        70
# 332       port-vila      VU -17.7338  168.3219        72
# 373         isangel      VU -19.5500  169.2667        69
# 405     nova sintra      CV  14.8667  -24.7167        59
# 427          pandan      PH  14.0453  124.1694        72
# 442   mount gambier      AU -37.8333  140.7667        66
# 448         mandera      KE   3.9366   41.8670        45
# 460        chetwayi      IN  10.5333   76.0500        55
# 465         le port      RE -20.9373   55.2919        74
# 468          sydney      AU -33.8679  151.2073        73
# 479         pathein      MM  16.7833   94.7333        41
# 528           tokar      SD  18.4254   37.7290        61
# 571        lakatoro      VU -16.0999  167.4164        74
# 600         yeppoon      AU -23.1333  150.7333        65
#
#                      Hotel Name
# 9                  فندق المدينه
# 38                 Paradise Inn
# 65         Margaret River Hotel
# 83               No hotel found
# 85                   City Hotel
# 105     Cocos Village Bungalows
# 153              No hotel found
# 165       Riverside Hotel Motel
# 207                Hotel Marlin
# 219             Escale Vacances
# 257                  グリーンリッチホテル
# 295                    海的顏色精品旅館
# 296      Hotel Chik Chik Namibe
# 310              No hotel found
# 321              No hotel found
# 324                Tropic Hotel
# 332  Holiday Inn Resort Vanuatu
# 373                 Tanna Lodge
# 405        Residência Ka Dencho
# 427              No hotel found
# 442  The Old Mount Gambier Gaol
# 448   Kornesh Hotel and Lodging
# 460                  ever green
# 465              No hotel found
# 468         The Fullerton Hotel
# 479                Taan Taan Ta
# 528              No hotel found
# 571              No hotel found
# 600       Blossom's on Seaspray

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points("Lng","Lat",
                                  geo=True,
                                  frame_width = 700,
                                  frame_height = 500, 
                                  color="City",
                                  alpha= 1,
                                  tiles="OSM",
                                  hover_cols=["Hotel Name", "Humidity", "Country"])

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Humidity,Country)
