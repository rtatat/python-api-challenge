# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 637

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    
    
    # Create endpoint URL with each city
    city_url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | guarapari
# Processing Record 2 of Set 1 | kodiak
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | haiku-pauwela
# Processing Record 6 of Set 1 | talnakh
# Processing Record 7 of Set 1 | howrah
# Processing Record 8 of Set 1 | port-aux-francais
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | oodweyne
# Processing Record 11 of Set 1 | weining
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | zouerate
# Processing Record 14 of Set 1 | papatowai
# Processing Record 15 of Set 1 | bethel
# Processing Record 16 of Set 1 | adamstown
# Processing Record 17 of Set 1 | isle of lewis
# City not found. Skipping...
# Processing Record 18 of Set 1 | san patricio
# Processing Record 19 of Set 1 | nefta
# Processing Record 20 of Set 1 | bridgewater
# Processing Record 21 of Set 1 | tiksi
# Processing Record 22 of Set 1 | musay'id
# City not found. Skipping...
# Processing Record 23 of Set 1 | uige
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | mahibadhoo
# Processing Record 26 of Set 1 | blackmans bay
# Processing Record 27 of Set 1 | whitehorse
# Processing Record 28 of Set 1 | invercargill
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | manistee
# Processing Record 31 of Set 1 | jajpur
# Processing Record 32 of Set 1 | nguigmi
# Processing Record 33 of Set 1 | saldanha
# Processing Record 34 of Set 1 | iqaluit
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | jimaguayu
# City not found. Skipping...
# Processing Record 37 of Set 1 | enewetak
# Processing Record 38 of Set 1 | olyokminsk
# Processing Record 39 of Set 1 | tolanaro
# Processing Record 40 of Set 1 | bilibino
# Processing Record 41 of Set 1 | sikonge
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | okhotsk
# Processing Record 44 of Set 1 | arteche
# Processing Record 45 of Set 1 | thurso
# Processing Record 46 of Set 1 | gadzhiyevo
# Processing Record 47 of Set 1 | oriximina
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | nema
# Processing Record 50 of Set 1 | sitka
# Processing Record 0 of Set 2 | edinburgh of the seven seas
# Processing Record 1 of Set 2 | quellon
# Processing Record 2 of Set 2 | geraldton
# Processing Record 3 of Set 2 | ambovombe
# Processing Record 4 of Set 2 | grytviken
# Processing Record 5 of Set 2 | utrik
# Processing Record 6 of Set 2 | klyuchi
# Processing Record 7 of Set 2 | ocean pointe
# City not found. Skipping...
# Processing Record 8 of Set 2 | retreat
# Processing Record 9 of Set 2 | brooks
# Processing Record 10 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 11 of Set 2 | saint-marc
# Processing Record 12 of Set 2 | fale old settlement
# Processing Record 13 of Set 2 | kargasok
# Processing Record 14 of Set 2 | isafjordur
# Processing Record 15 of Set 2 | nar'yan-mar
# Processing Record 16 of Set 2 | kibaya
# Processing Record 17 of Set 2 | kihoku-cho
# Processing Record 18 of Set 2 | mejit
# Processing Record 19 of Set 2 | guerrero negro
# Processing Record 20 of Set 2 | margaret river
# Processing Record 21 of Set 2 | puerto natales
# Processing Record 22 of Set 2 | formosa do rio preto
# Processing Record 23 of Set 2 | tercan
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | canutama
# Processing Record 26 of Set 2 | ba
# City not found. Skipping...
# Processing Record 27 of Set 2 | port saint john's
# Processing Record 28 of Set 2 | chonchi
# Processing Record 29 of Set 2 | wailua homesteads
# Processing Record 30 of Set 2 | stanley
# Processing Record 31 of Set 2 | letlhakeng
# Processing Record 32 of Set 2 | chui
# Processing Record 33 of Set 2 | murzuq
# Processing Record 34 of Set 2 | puerto deseado
# Processing Record 35 of Set 2 | vershino-darasunskiy
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | constantia
# Processing Record 38 of Set 2 | hamilton
# Processing Record 39 of Set 2 | savave village
# City not found. Skipping...
# Processing Record 40 of Set 2 | lamarque
# Processing Record 41 of Set 2 | lompoc
# Processing Record 42 of Set 2 | nuku'alofa
# Processing Record 43 of Set 2 | kashgar
# Processing Record 44 of Set 2 | cidreira
# Processing Record 45 of Set 2 | olonkinbyen
# Processing Record 46 of Set 2 | narvik
# Processing Record 47 of Set 2 | atbara
# Processing Record 48 of Set 2 | san antonio de pale
# Processing Record 49 of Set 2 | waitangi
# Processing Record 0 of Set 3 | bemidji
# Processing Record 1 of Set 3 | kapit
# Processing Record 2 of Set 3 | keflavik
# Processing Record 3 of Set 3 | inhambane
# Processing Record 4 of Set 3 | sakaiminato
# Processing Record 5 of Set 3 | san juan tepa
# Processing Record 6 of Set 3 | la gi
# Processing Record 7 of Set 3 | severo-yeniseyskiy
# Processing Record 8 of Set 3 | lambayeque
# Processing Record 9 of Set 3 | hacienda huancane
# Processing Record 10 of Set 3 | fortuna
# Processing Record 11 of Set 3 | badger
# Processing Record 12 of Set 3 | west island
# Processing Record 13 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 14 of Set 3 | wakkanai
# Processing Record 15 of Set 3 | sao tome
# Processing Record 16 of Set 3 | tamanrasset
# Processing Record 17 of Set 3 | thompson
# Processing Record 18 of Set 3 | kharp
# Processing Record 19 of Set 3 | yelizovo
# Processing Record 20 of Set 3 | riyadh
# Processing Record 21 of Set 3 | atasu
# Processing Record 22 of Set 3 | revda
# Processing Record 23 of Set 3 | aras-asan
# Processing Record 24 of Set 3 | cabo san lucas
# Processing Record 25 of Set 3 | marsa alam
# Processing Record 26 of Set 3 | lukoyanov
# Processing Record 27 of Set 3 | broome
# Processing Record 28 of Set 3 | hawaiian paradise park
# Processing Record 29 of Set 3 | dungannon
# Processing Record 30 of Set 3 | huillapima
# Processing Record 31 of Set 3 | maua
# Processing Record 32 of Set 3 | yigo village
# Processing Record 33 of Set 3 | selfoss
# Processing Record 34 of Set 3 | kyzyl-suu
# Processing Record 35 of Set 3 | binzhou
# Processing Record 36 of Set 3 | santa marta
# Processing Record 37 of Set 3 | rupert
# Processing Record 38 of Set 3 | new norfolk
# Processing Record 39 of Set 3 | san luis de la loma
# Processing Record 40 of Set 3 | cockburn town
# Processing Record 41 of Set 3 | labrador city
# Processing Record 42 of Set 3 | lianhe
# Processing Record 43 of Set 3 | ilulissat
# Processing Record 44 of Set 3 | sinop
# Processing Record 45 of Set 3 | galliano
# Processing Record 46 of Set 3 | ilhabela
# Processing Record 47 of Set 3 | aykhal
# Processing Record 48 of Set 3 | kolonia town
# Processing Record 49 of Set 3 | tazacorte
# Processing Record 0 of Set 4 | malango
# Processing Record 1 of Set 4 | tatarsk
# Processing Record 2 of Set 4 | midvagur
# Processing Record 3 of Set 4 | tingo maria
# Processing Record 4 of Set 4 | fort mcmurray
# Processing Record 5 of Set 4 | bubaque
# Processing Record 6 of Set 4 | rybinsk
# Processing Record 7 of Set 4 | kuala terengganu
# Processing Record 8 of Set 4 | fort bragg
# Processing Record 9 of Set 4 | ust-nera
# Processing Record 10 of Set 4 | kattivakkam
# Processing Record 11 of Set 4 | kayangel
# Processing Record 12 of Set 4 | nishinoomote
# Processing Record 13 of Set 4 | sola
# Processing Record 14 of Set 4 | magadan
# Processing Record 15 of Set 4 | onega
# Processing Record 16 of Set 4 | tahe
# Processing Record 17 of Set 4 | odemira
# Processing Record 18 of Set 4 | dudinka
# Processing Record 19 of Set 4 | kolonia
# Processing Record 20 of Set 4 | lionel town
# Processing Record 21 of Set 4 | iskateley
# Processing Record 22 of Set 4 | newnham
# Processing Record 23 of Set 4 | qandala
# Processing Record 24 of Set 4 | harper
# Processing Record 25 of Set 4 | ati
# Processing Record 26 of Set 4 | shush
# Processing Record 27 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 28 of Set 4 | vinces
# Processing Record 29 of Set 4 | st. john's
# Processing Record 30 of Set 4 | tura
# Processing Record 31 of Set 4 | mersa matruh
# Processing Record 32 of Set 4 | saudarkrokur
# Processing Record 33 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 34 of Set 4 | rexburg
# Processing Record 35 of Set 4 | san vicente
# Processing Record 36 of Set 4 | punta arenas
# Processing Record 37 of Set 4 | berdigestyakh
# Processing Record 38 of Set 4 | bredasdorp
# Processing Record 39 of Set 4 | kourou
# Processing Record 40 of Set 4 | kiama
# Processing Record 41 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 4 | iguape
# Processing Record 43 of Set 4 | belyy yar
# Processing Record 44 of Set 4 | puerto baquerizo moreno
# Processing Record 45 of Set 4 | rio gallegos
# Processing Record 46 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 47 of Set 4 | uturoa
# Processing Record 48 of Set 4 | atafu village
# Processing Record 49 of Set 4 | maktar
# Processing Record 0 of Set 5 | greymouth
# Processing Record 1 of Set 5 | plastun
# Processing Record 2 of Set 5 | la ronge
# Processing Record 3 of Set 5 | susaki
# Processing Record 4 of Set 5 | prince rupert
# Processing Record 5 of Set 5 | nandikotkur
# Processing Record 6 of Set 5 | port moresby
# Processing Record 7 of Set 5 | tikhvin
# Processing Record 8 of Set 5 | alice springs
# Processing Record 9 of Set 5 | mount pearl
# Processing Record 10 of Set 5 | aasiaat
# Processing Record 11 of Set 5 | poltavka
# Processing Record 12 of Set 5 | koryazhma
# Processing Record 13 of Set 5 | nouadhibou
# Processing Record 14 of Set 5 | gamba
# Processing Record 15 of Set 5 | odienne
# Processing Record 16 of Set 5 | farafangana
# Processing Record 17 of Set 5 | udachny
# Processing Record 18 of Set 5 | ulladulla
# Processing Record 19 of Set 5 | lorengau
# City not found. Skipping...
# Processing Record 20 of Set 5 | qaqortoq
# Processing Record 21 of Set 5 | grand falls-windsor
# Processing Record 22 of Set 5 | shemysheyka
# Processing Record 23 of Set 5 | posto fiscal rolim de moura
# Processing Record 24 of Set 5 | beli
# Processing Record 25 of Set 5 | salinas
# Processing Record 26 of Set 5 | ampanihy
# Processing Record 27 of Set 5 | rongelap
# Processing Record 28 of Set 5 | auki
# Processing Record 29 of Set 5 | kataragama
# City not found. Skipping...
# Processing Record 30 of Set 5 | howard springs
# Processing Record 31 of Set 5 | usogorsk
# Processing Record 32 of Set 5 | port mathurin
# Processing Record 33 of Set 5 | soriano nel cimino
# Processing Record 34 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 5 | dalandzadgad
# Processing Record 36 of Set 5 | astaneh-ye ashrafiyeh
# Processing Record 37 of Set 5 | hwange
# Processing Record 38 of Set 5 | leiyang
# Processing Record 39 of Set 5 | vorgashor
# Processing Record 40 of Set 5 | acarau
# Processing Record 41 of Set 5 | holualoa
# Processing Record 42 of Set 5 | khuzdar
# Processing Record 43 of Set 5 | east london
# Processing Record 44 of Set 5 | vorkuta
# Processing Record 45 of Set 5 | alta
# Processing Record 46 of Set 5 | port blair
# Processing Record 47 of Set 5 | sitangkai
# Processing Record 48 of Set 5 | ishpeming
# Processing Record 49 of Set 5 | huilong
# Processing Record 0 of Set 6 | santa terezinha
# Processing Record 1 of Set 6 | wanzleben
# Processing Record 2 of Set 6 | horta
# Processing Record 3 of Set 6 | point vernon
# Processing Record 4 of Set 6 | shache
# Processing Record 5 of Set 6 | ust'-kut
# Processing Record 6 of Set 6 | coeur d'alene
# Processing Record 7 of Set 6 | college
# Processing Record 8 of Set 6 | sisimiut
# Processing Record 9 of Set 6 | kaa-khem
# Processing Record 10 of Set 6 | pamandzi
# Processing Record 11 of Set 6 | aswan
# Processing Record 12 of Set 6 | vila franca do campo
# Processing Record 13 of Set 6 | flying fish cove
# Processing Record 14 of Set 6 | vilyuchinsk
# Processing Record 15 of Set 6 | sterling
# Processing Record 16 of Set 6 | sawai madhopur
# Processing Record 17 of Set 6 | aroma
# Processing Record 18 of Set 6 | nhamunda
# Processing Record 19 of Set 6 | shimoda
# Processing Record 20 of Set 6 | kingston
# Processing Record 21 of Set 6 | nago
# Processing Record 22 of Set 6 | saipan
# Processing Record 23 of Set 6 | brookings
# Processing Record 24 of Set 6 | kapuskasing
# Processing Record 25 of Set 6 | williams lake
# Processing Record 26 of Set 6 | neryungri
# Processing Record 27 of Set 6 | krasnogorskiy
# Processing Record 28 of Set 6 | hayma'
# City not found. Skipping...
# Processing Record 29 of Set 6 | pestravka
# Processing Record 30 of Set 6 | devils lake
# Processing Record 31 of Set 6 | hachinohe
# Processing Record 32 of Set 6 | powell
# Processing Record 33 of Set 6 | trinity beach
# Processing Record 34 of Set 6 | kasongo-lunda
# Processing Record 35 of Set 6 | mildura
# Processing Record 36 of Set 6 | san luis
# Processing Record 37 of Set 6 | thinadhoo
# Processing Record 38 of Set 6 | tralee
# Processing Record 39 of Set 6 | marinhais
# Processing Record 40 of Set 6 | lakhdaria
# Processing Record 41 of Set 6 | carnarvon
# Processing Record 42 of Set 6 | trujillo
# Processing Record 43 of Set 6 | mishkino
# Processing Record 44 of Set 6 | verkhnevilyuysk
# Processing Record 45 of Set 6 | nova vicosa
# Processing Record 46 of Set 6 | zhanaozen
# Processing Record 47 of Set 6 | kailua-kona
# Processing Record 48 of Set 6 | san rafael
# Processing Record 49 of Set 6 | portland
# Processing Record 0 of Set 7 | arthur's town
# City not found. Skipping...
# Processing Record 1 of Set 7 | vanimo
# Processing Record 2 of Set 7 | arta
# Processing Record 3 of Set 7 | gorgan
# Processing Record 4 of Set 7 | carupano
# Processing Record 5 of Set 7 | villa gesell
# Processing Record 6 of Set 7 | moyale
# Processing Record 7 of Set 7 | chaozhou
# Processing Record 8 of Set 7 | conde
# Processing Record 9 of Set 7 | vadodara
# Processing Record 10 of Set 7 | nizhniy odes
# Processing Record 11 of Set 7 | hengchun
# Processing Record 12 of Set 7 | namibe
# Processing Record 13 of Set 7 | melilla
# Processing Record 14 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 15 of Set 7 | tahmoor
# Processing Record 16 of Set 7 | kwangyang
# Processing Record 17 of Set 7 | barclayville
# Processing Record 18 of Set 7 | twon-brass
# Processing Record 19 of Set 7 | rabo de peixe
# Processing Record 20 of Set 7 | longyearbyen
# Processing Record 21 of Set 7 | talakan
# Processing Record 22 of Set 7 | timmins
# Processing Record 23 of Set 7 | valdivia
# Processing Record 24 of Set 7 | koubia
# Processing Record 25 of Set 7 | lihue
# Processing Record 26 of Set 7 | chibougamau
# Processing Record 27 of Set 7 | codrington
# Processing Record 28 of Set 7 | vanino
# Processing Record 29 of Set 7 | amungan
# Processing Record 30 of Set 7 | yanam
# Processing Record 31 of Set 7 | zaozersk
# Processing Record 32 of Set 7 | huarmey
# Processing Record 33 of Set 7 | peace river
# Processing Record 34 of Set 7 | cabugao
# Processing Record 35 of Set 7 | poso
# Processing Record 36 of Set 7 | luganville
# Processing Record 37 of Set 7 | coquimbo
# Processing Record 38 of Set 7 | tiadiaye
# Processing Record 39 of Set 7 | mangrol
# Processing Record 40 of Set 7 | cowansville
# Processing Record 41 of Set 7 | saint-pierre
# Processing Record 42 of Set 7 | walvis bay
# Processing Record 43 of Set 7 | ashland
# Processing Record 44 of Set 7 | burgersdorp
# Processing Record 45 of Set 7 | rio preto da eva
# Processing Record 46 of Set 7 | taoudenni
# Processing Record 47 of Set 7 | northam
# Processing Record 48 of Set 7 | georgetown
# Processing Record 49 of Set 7 | port-vila
# Processing Record 0 of Set 8 | cururupu
# Processing Record 1 of Set 8 | meknes
# Processing Record 2 of Set 8 | choma
# Processing Record 3 of Set 8 | nizhneangarsk
# Processing Record 4 of Set 8 | mili
# Processing Record 5 of Set 8 | tarko-sale
# Processing Record 6 of Set 8 | cedral
# Processing Record 7 of Set 8 | nyurba
# Processing Record 8 of Set 8 | richards bay
# Processing Record 9 of Set 8 | polyarnyy
# Processing Record 10 of Set 8 | hasaki
# Processing Record 11 of Set 8 | nizhnesortymskiy
# Processing Record 12 of Set 8 | merizo village
# Processing Record 13 of Set 8 | buka
# Processing Record 14 of Set 8 | ust'-ilimsk
# Processing Record 15 of Set 8 | korla
# Processing Record 16 of Set 8 | mount isa
# Processing Record 17 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 18 of Set 8 | sena madureira
# Processing Record 19 of Set 8 | maragogi
# Processing Record 20 of Set 8 | ihosy
# Processing Record 21 of Set 8 | bridgetown
# Processing Record 22 of Set 8 | dubai
# Processing Record 23 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 24 of Set 8 | lupane
# Processing Record 25 of Set 8 | salekhard
# Processing Record 26 of Set 8 | kill devil hills
# Processing Record 27 of Set 8 | cedeira
# Processing Record 28 of Set 8 | bardai
# Processing Record 29 of Set 8 | tangalle
# Processing Record 30 of Set 8 | belmonte
# Processing Record 31 of Set 8 | ulan bator
# Processing Record 32 of Set 8 | akrehamn
# Processing Record 33 of Set 8 | las lomitas
# Processing Record 34 of Set 8 | mirny
# Processing Record 35 of Set 8 | anadyr
# Processing Record 36 of Set 8 | praia da vitoria
# Processing Record 37 of Set 8 | juye
# Processing Record 38 of Set 8 | az zubayr
# Processing Record 39 of Set 8 | mossel bay
# Processing Record 40 of Set 8 | luanda
# Processing Record 41 of Set 8 | tazovsky
# Processing Record 42 of Set 8 | isangel
# Processing Record 43 of Set 8 | las tablas
# Processing Record 44 of Set 8 | luderitz
# Processing Record 45 of Set 8 | kindu
# Processing Record 46 of Set 8 | shihezi
# Processing Record 47 of Set 8 | barrouallie
# Processing Record 48 of Set 8 | palembang
# Processing Record 49 of Set 8 | tchibanga
# Processing Record 0 of Set 9 | mahdia
# Processing Record 1 of Set 9 | udayagiri
# Processing Record 2 of Set 9 | sheridan
# Processing Record 3 of Set 9 | tezu
# Processing Record 4 of Set 9 | saint augustine shores
# Processing Record 5 of Set 9 | dunedin
# Processing Record 6 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 7 of Set 9 | maddela
# Processing Record 8 of Set 9 | dabola
# Processing Record 9 of Set 9 | ar rahad
# Processing Record 10 of Set 9 | palikir - national government center
# Processing Record 11 of Set 9 | marks
# Processing Record 12 of Set 9 | espinosa
# Processing Record 13 of Set 9 | shortandy
# Processing Record 14 of Set 9 | tome acu
# Processing Record 15 of Set 9 | happy valley-goose bay
# Processing Record 16 of Set 9 | ancud
# Processing Record 17 of Set 9 | suhbaatar
# Processing Record 18 of Set 9 | xinzhou
# Processing Record 19 of Set 9 | at-bashi
# Processing Record 20 of Set 9 | kapa'a
# Processing Record 21 of Set 9 | pimentel
# Processing Record 22 of Set 9 | whyalla stuart
# City not found. Skipping...
# Processing Record 23 of Set 9 | igaci
# Processing Record 24 of Set 9 | labytnangi
# Processing Record 25 of Set 9 | tan-tan
# Processing Record 26 of Set 9 | nova sintra
# Processing Record 27 of Set 9 | yoloten
# Processing Record 28 of Set 9 | feltre
# Processing Record 29 of Set 9 | pervomayskoye
# Processing Record 30 of Set 9 | pacific grove
# Processing Record 31 of Set 9 | touros
# Processing Record 32 of Set 9 | sao joao da barra
# Processing Record 33 of Set 9 | lecheng
# Processing Record 34 of Set 9 | san andres
# Processing Record 35 of Set 9 | braunlage
# Processing Record 36 of Set 9 | beyneu
# Processing Record 37 of Set 9 | punta del este
# Processing Record 38 of Set 9 | muli
# Processing Record 39 of Set 9 | montepuez
# Processing Record 40 of Set 9 | mugia
# Processing Record 41 of Set 9 | kachug
# Processing Record 42 of Set 9 | inarajan village
# Processing Record 43 of Set 9 | nemuro
# Processing Record 44 of Set 9 | hadibu
# Processing Record 45 of Set 9 | newman
# Processing Record 46 of Set 9 | kuruman
# Processing Record 47 of Set 9 | queenstown
# Processing Record 48 of Set 9 | pandan
# Processing Record 49 of Set 9 | crane
# Processing Record 0 of Set 10 | nabire
# Processing Record 1 of Set 10 | susuman
# Processing Record 2 of Set 10 | essaouira
# Processing Record 3 of Set 10 | katsuura
# Processing Record 4 of Set 10 | mahina
# Processing Record 5 of Set 10 | igarka
# Processing Record 6 of Set 10 | talara
# Processing Record 7 of Set 10 | piti village
# Processing Record 8 of Set 10 | niort
# Processing Record 9 of Set 10 | road town
# Processing Record 10 of Set 10 | siatista
# Processing Record 11 of Set 10 | lauro de freitas
# Processing Record 12 of Set 10 | mar del plata
# Processing Record 13 of Set 10 | mount gambier
# Processing Record 14 of Set 10 | manaure
# Processing Record 15 of Set 10 | porto novo
# Processing Record 16 of Set 10 | narasannapeta
# Processing Record 17 of Set 10 | qulsary
# Processing Record 18 of Set 10 | cestos city
# Processing Record 19 of Set 10 | mandera
# Processing Record 20 of Set 10 | rasht
# Processing Record 21 of Set 10 | ostersund
# Processing Record 22 of Set 10 | ak-suu
# Processing Record 23 of Set 10 | nadym
# Processing Record 24 of Set 10 | krasnoufimsk
# Processing Record 25 of Set 10 | la passe
# Processing Record 26 of Set 10 | akureyri
# Processing Record 27 of Set 10 | hargeysa
# Processing Record 28 of Set 10 | port lincoln
# Processing Record 29 of Set 10 | xinyuan
# Processing Record 30 of Set 10 | long beach
# Processing Record 31 of Set 10 | chetwayi
# Processing Record 32 of Set 10 | dzhangala
# Processing Record 33 of Set 10 | kananga
# Processing Record 34 of Set 10 | mogadishu
# Processing Record 35 of Set 10 | macae
# Processing Record 36 of Set 10 | le port
# Processing Record 37 of Set 10 | hotan
# Processing Record 38 of Set 10 | embu guacu
# Processing Record 39 of Set 10 | sydney
# Processing Record 40 of Set 10 | bandarbeyla
# Processing Record 41 of Set 10 | kittila
# Processing Record 42 of Set 10 | severobaykal'sk
# Processing Record 43 of Set 10 | micheweni
# Processing Record 44 of Set 10 | kupang
# Processing Record 45 of Set 10 | terrasson-lavilledieu
# Processing Record 46 of Set 10 | harstad
# Processing Record 47 of Set 10 | sokoni
# Processing Record 48 of Set 10 | delta
# Processing Record 49 of Set 10 | buncrana
# Processing Record 0 of Set 11 | pathein
# Processing Record 1 of Set 11 | caleta de carquin
# Processing Record 2 of Set 11 | jianshui
# Processing Record 3 of Set 11 | mayya
# Processing Record 4 of Set 11 | puerto aysen
# Processing Record 5 of Set 11 | ocean shores
# Processing Record 6 of Set 11 | fada
# Processing Record 7 of Set 11 | lycksele
# Processing Record 8 of Set 11 | jiangyou
# Processing Record 9 of Set 11 | dakhla
# Processing Record 10 of Set 11 | tosontsengel
# Processing Record 11 of Set 11 | siem reap
# Processing Record 12 of Set 11 | jackson
# Processing Record 13 of Set 11 | remire-montjoly
# Processing Record 14 of Set 11 | weno
# Processing Record 15 of Set 11 | rawai
# Processing Record 16 of Set 11 | guadalupe y calvo
# Processing Record 17 of Set 11 | bam
# Processing Record 18 of Set 11 | ghat
# Processing Record 19 of Set 11 | bamboo flat
# Processing Record 20 of Set 11 | youkounkoun
# Processing Record 21 of Set 11 | yanbu
# Processing Record 22 of Set 11 | kodok
# City not found. Skipping...
# Processing Record 23 of Set 11 | moraleja
# Processing Record 24 of Set 11 | ola
# Processing Record 25 of Set 11 | bangkalan
# Processing Record 26 of Set 11 | callao
# Processing Record 27 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 11 | chinde
# Processing Record 29 of Set 11 | crookston
# Processing Record 30 of Set 11 | axim
# Processing Record 31 of Set 11 | port alfred
# Processing Record 32 of Set 11 | haapajarvi
# Processing Record 33 of Set 11 | santa maria
# Processing Record 34 of Set 11 | lerwick
# Processing Record 35 of Set 11 | kavieng
# Processing Record 36 of Set 11 | phuthaditjhaba
# Processing Record 37 of Set 11 | mantua
# Processing Record 38 of Set 11 | lower sackville
# Processing Record 39 of Set 11 | emerald
# Processing Record 40 of Set 11 | luwuk
# Processing Record 41 of Set 11 | owen sound
# Processing Record 42 of Set 11 | susanville
# Processing Record 43 of Set 11 | keelung
# Processing Record 44 of Set 11 | pozanti
# Processing Record 45 of Set 11 | muravlenko
# Processing Record 46 of Set 11 | swift current
# Processing Record 47 of Set 11 | nagqu
# Processing Record 48 of Set 11 | vila velha
# Processing Record 49 of Set 11 | fort st. john
# Processing Record 0 of Set 12 | souillac
# Processing Record 1 of Set 12 | tokar
# Processing Record 2 of Set 12 | salavan
# Processing Record 3 of Set 12 | ursulo galvan
# Processing Record 4 of Set 12 | pitimbu
# Processing Record 5 of Set 12 | orange park
# Processing Record 6 of Set 12 | meiktila
# Processing Record 7 of Set 12 | raja
# Processing Record 8 of Set 12 | galesong
# Processing Record 9 of Set 12 | mil'kovo
# Processing Record 10 of Set 12 | sao vicente
# Processing Record 11 of Set 12 | beniganim
# Processing Record 12 of Set 12 | kralendijk
# Processing Record 13 of Set 12 | brokopondo
# Processing Record 14 of Set 12 | rosa zarate
# Processing Record 15 of Set 12 | melendugno
# Processing Record 16 of Set 12 | saugor
# Processing Record 17 of Set 12 | oranjemund
# Processing Record 18 of Set 12 | milove
# Processing Record 19 of Set 12 | ardestan
# Processing Record 20 of Set 12 | shitanjing
# Processing Record 21 of Set 12 | necocli
# Processing Record 22 of Set 12 | klishkivtsi
# Processing Record 23 of Set 12 | gap
# Processing Record 24 of Set 12 | pisco
# Processing Record 25 of Set 12 | igrim
# Processing Record 26 of Set 12 | eyl
# Processing Record 27 of Set 12 | pontianak
# Processing Record 28 of Set 12 | inari
# Processing Record 29 of Set 12 | nakhon si thammarat
# Processing Record 30 of Set 12 | qurayyat
# Processing Record 31 of Set 12 | armacao de buzios
# Processing Record 32 of Set 12 | harnosand
# Processing Record 33 of Set 12 | minacu
# City not found. Skipping...
# Processing Record 34 of Set 12 | pont rouge
# Processing Record 35 of Set 12 | kirakira
# Processing Record 36 of Set 12 | borogontsy
# Processing Record 37 of Set 12 | turkeli
# Processing Record 38 of Set 12 | matias barbosa
# Processing Record 39 of Set 12 | kavaratti
# Processing Record 40 of Set 12 | suwayr
# Processing Record 41 of Set 12 | dera bugti
# Processing Record 42 of Set 12 | seogwipo
# City not found. Skipping...
# Processing Record 43 of Set 12 | bloemfontein
# Processing Record 44 of Set 12 | karratha
# Processing Record 45 of Set 12 | minot air force base
# Processing Record 46 of Set 12 | lakatoro
# Processing Record 47 of Set 12 | bestobe
# Processing Record 48 of Set 12 | fandriana
# Processing Record 49 of Set 12 | bebedja
# Processing Record 0 of Set 13 | khandyga
# Processing Record 1 of Set 13 | nantucket
# Processing Record 2 of Set 13 | al hufuf
# Processing Record 3 of Set 13 | srivardhan
# Processing Record 4 of Set 13 | rikaze
# Processing Record 5 of Set 13 | garachico
# Processing Record 6 of Set 13 | shalkar
# Processing Record 7 of Set 13 | nurota
# Processing Record 8 of Set 13 | jinchang
# Processing Record 9 of Set 13 | tortoli
# Processing Record 10 of Set 13 | badr hunayn
# Processing Record 11 of Set 13 | vadso
# Processing Record 12 of Set 13 | chernyshkovskiy
# Processing Record 13 of Set 13 | axum
# Processing Record 14 of Set 13 | taro
# Processing Record 15 of Set 13 | al wafrah
# Processing Record 16 of Set 13 | colonia
# Processing Record 17 of Set 13 | bokovskaya
# Processing Record 18 of Set 13 | sint michiel liber
# Processing Record 19 of Set 13 | ariguani
# Processing Record 20 of Set 13 | dabhoi
# Processing Record 21 of Set 13 | al mayadin
# Processing Record 22 of Set 13 | hexham
# Processing Record 23 of Set 13 | pirot
# Processing Record 24 of Set 13 | tanjung pandan
# Processing Record 25 of Set 13 | yeppoon
# Processing Record 26 of Set 13 | bozoum
# Processing Record 27 of Set 13 | gandajika
# Processing Record 28 of Set 13 | sagalo
# City not found. Skipping...
# Processing Record 29 of Set 13 | americus
# Processing Record 30 of Set 13 | la cruz
# Processing Record 31 of Set 13 | alibag
# Processing Record 32 of Set 13 | bayanaul
# Processing Record 33 of Set 13 | sakata
# Processing Record 34 of Set 13 | laoag
# Processing Record 35 of Set 13 | afaahiti
# Processing Record 36 of Set 13 | la rinconada
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          611
# Lat           611
# Lng           611
# Max Temp      611
# Humidity      611
# Cloudiness    611
# Wind Speed    611
# Country       611
# Date          611
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      guarapari -20.6667  -40.4975     23.27        92         100
# 1         kodiak  57.7900 -152.4072     -1.27        93         100
# 2         albany  42.6001  -73.9662      0.78        80         100
# 3   puerto ayora  -0.7393  -90.3518     24.19        96          15
# 4  haiku-pauwela  20.9219 -156.3051     23.01        75          20
#
#    Wind Speed Country        Date
# 0        3.69      BR  1704085006
# 1        2.57      US  1704085049
# 2        0.62      US  1704085051
# 3        2.91      EC  1704085053
# 4        3.60      US  1704085055

# %%
# Converting Date to something more useable
city_data_df['Date']=(pd.to_datetime(city_data_df['Date'],unit='s')).dt.date
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      guarapari -20.6667  -40.4975     23.27        92         100
# 1         kodiak  57.7900 -152.4072     -1.27        93         100
# 2         albany  42.6001  -73.9662      0.78        80         100
# 3   puerto ayora  -0.7393  -90.3518     24.19        96          15
# 4  haiku-pauwela  20.9219 -156.3051     23.01        75          20
#
#    Wind Speed Country        Date
# 0        3.69      BR  2024-01-01
# 1        2.57      US  2024-01-01
# 2        0.62      US  2024-01-01
# 3        2.91      EC  2024-01-01
# 4        3.60      US  2024-01-01

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            guarapari -20.6667  -40.4975     23.27        92         100
# 1               kodiak  57.7900 -152.4072     -1.27        93         100
# 2               albany  42.6001  -73.9662      0.78        80         100
# 3         puerto ayora  -0.7393  -90.3518     24.19        96          15
# 4        haiku-pauwela  20.9219 -156.3051     23.01        75          20
#
#          Wind Speed Country        Date
# City_ID
# 0              3.69      BR  2024-01-01
# 1              2.57      US  2024-01-01
# 2              0.62      US  2024-01-01
# 3              2.91      EC  2024-01-01
# 4              3.60      US  2024-01-01

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_latitude = city_data_df["Lat"]
city_temp = city_data_df["Max Temp"]
date = city_data_df["Date"].min()
# New dataframe for this data
lat_temp_df = pd.DataFrame({"Latitude":city_latitude, "Max Temperature (C)":city_temp})
# Setting axis
x_lat_temp = lat_temp_df["Latitude"]
y_lat_temp = lat_temp_df["Max Temperature (C)"]
# Making the graph
plt.scatter(x_lat_temp,y_lat_temp,marker = "o",facecolors = "orange", edgecolors = "black")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_humidity = city_data_df["Humidity"]
plt.scatter(city_latitude,city_humidity,marker = "o",facecolors = "orange", edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity ({date})")

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_cloudiness = city_data_df["Cloudiness"]
plt.scatter(city_latitude, city_cloudiness, marker = "o", facecolors = "orange", edgecolors = "black")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({date})")

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_wspeed = city_data_df["Wind Speed"]
plt.scatter(city_latitude, city_wspeed, marker = "o", facecolors = "orange", edgecolors = "black")
plt.title(f"City Latitude vs Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")

# Incorporate the other graph properties
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0,:]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1               kodiak  57.7900 -152.4072     -1.27        93         100
# 2               albany  42.6001  -73.9662      0.78        80         100
# 4        haiku-pauwela  20.9219 -156.3051     23.01        75          20
# 5              talnakh  69.4865   88.3972    -31.00       100         100
# 6               howrah  22.5892   88.3103     18.00        82           0
#
#          Wind Speed Country        Date
# City_ID
# 1              2.57      US  2024-01-01
# 2              0.62      US  2024-01-01
# 4              3.60      US  2024-01-01
# 5              1.47      RU  2024-01-01
# 6              2.06      IN  2024-01-01

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                guarapari -20.6667 -40.4975     23.27        92         100
# 3             puerto ayora  -0.7393 -90.3518     24.19        96          15
# 7        port-aux-francais -49.3500  70.2167      5.42        78          71
# 8           port elizabeth -33.9180  25.5701     20.05        96         100
# 11                 ushuaia -54.8000 -68.3000      8.81        61           0
#
#          Wind Speed Country        Date
# City_ID
# 0              3.69      BR  2024-01-01
# 3              2.91      EC  2024-01-01
# 7             14.24      TF  2024-01-01
# 8              3.60      ZA  2024-01-01
# 11             7.20      AR  2024-01-01

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
max_north_temp = northern_hemi_df["Max Temp"]
north_lat = northern_hemi_df["Lat"]
plt.scatter(north_lat, max_north_temp, marker = "o", facecolors = "purple")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Linear Regression of The Maximum Temperatures in Northern Hemisphere Cities")
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat,max_north_temp)
reg_nt = north_lat * slope + intercept
leq_nt = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
plt.plot(north_lat, reg_nt, "r-")
plt.annotate(leq_nt, (10,-30), fontsize = 17, color = "red")
# Printing the r-value comment
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: -0.8927

# %%
# Linear regression on Southern Hemisphere
max_south_temp = southern_hemi_df["Max Temp"]
south_lat = southern_hemi_df["Lat"]
plt.scatter(south_lat, max_south_temp, marker = "o", facecolors = "purple")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("Linear Regression of The Maximum Temperatures in Southern Hemisphere Cities")
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat,max_south_temp)
reg_st = south_lat * slope + intercept
leq_st = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
plt.plot(south_lat, reg_st, "r-")
plt.annotate(leq_st, (-50,38), fontsize = 17, color = "red")
# Printing the r-value comment
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: 0.6078

# %% [markdown]
# **Discussion about the linear relationship:** It can be observed that as the latitude approaches 0, the maximum temperature increases. As the 0 degree latitude refers to the equator, it can be stated that cities situated on or near the equator can be expected to have greater maximum temperatures. With r-values of -0.8927 and 0.6078, meaning that there is a strong relationship and a somewhat strong relationship between temperatures and latitude for the northern and southern cities respectively.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
north_hum = northern_hemi_df["Humidity"]
north_lat = northern_hemi_df["Lat"]
plt.scatter(north_lat, north_hum, marker = "o", facecolors = "purple")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Linear Regression of The Humidity in Northern Hemisphere Cities")
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat,north_hum)
reg_nh = north_lat * slope + intercept
leq_nh = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
plt.plot(north_lat, reg_nh, "r-")
plt.annotate(leq_nh, (50,20), fontsize = 17, color = "red")
# Printing the r-value comment
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: 0.4386

# %%
# Southern Hemisphere
south_hum = southern_hemi_df["Humidity"]
south_lat = southern_hemi_df["Lat"]
plt.scatter(south_lat, south_hum, marker = "o", facecolors = "purple")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Linear Regression of The Humidity in Southern Hemisphere Cities")
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat,south_hum)
reg_sh = south_lat * slope + intercept
leq_sh = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
plt.plot(south_lat, reg_sh, "r-")
plt.annotate(leq_sh, (-53,20), fontsize = 17, color = "red")
# Printing the r-value comment
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: 0.2426

# %% [markdown]
# **Discussion about the linear relationship:** It can be observed that as the latitude increases, the observed humidity increases as well, but as the r-value is only 0.4386, the relationship between the two is only moderately positive. With the southern hemisphere, as the latitude grows closer to 0, the humidity-latitude relationship is very slightly positive, due to the r-value of 0.2426.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
north_cld = northern_hemi_df["Cloudiness"]
north_lat = northern_hemi_df["Lat"]
plt.scatter(north_lat, north_cld, marker = "o", facecolors = "purple")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Linear Regression of The Cloudiness in Northern Hemisphere Cities")
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat,north_cld)
reg_nc = north_lat * slope + intercept
leq_nc = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
plt.plot(north_lat, reg_nc, "r-")
plt.annotate(leq_nc, (50,2), fontsize = 17, color = "red")
# Printing the r-value comment
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: 0.3101

# %%
# Southern Hemisphere
south_cld = southern_hemi_df["Cloudiness"]
south_lat = southern_hemi_df["Lat"]
plt.scatter(south_lat, south_cld, marker = "o", facecolors = "purple")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Linear Regression of The Cloudiness in Southern Hemisphere Cities")
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat,south_cld)
reg_sc = south_lat * slope + intercept
leq_sc = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
plt.plot(south_lat, reg_sc, "r-")
plt.annotate(leq_sc, (-55,11), fontsize = 17, color = "red")
# Printing the r-value comment
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: 0.0815

# %% [markdown]
# **Discussion about the linear relationship:** It can be observed in the northern hemisphere that there is only a slightly strong positive relationship between cloudiness and latitude, indicating that as latitude increases, so does cloudiness. This is due to the r-value of 0.3101. In the southern hemisphere however, there is essentially no correlation between latitude and cloudiness, due to the r-value of 0.0815.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
north_wnd = northern_hemi_df["Wind Speed"]
north_lat = northern_hemi_df["Lat"]
plt.scatter(north_lat, north_wnd, marker = "o", facecolors = "purple")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Linear Regression of The Wind Speed in Northern Hemisphere Cities")
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat,north_wnd)
reg_nw = north_lat * slope + intercept
leq_nw = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
plt.plot(north_lat, reg_nw, "r-")
plt.annotate(leq_nc, (10,14), fontsize = 17, color = "red")
# Printing the r-value comment
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: 0.0573

# %%
# Southern Hemisphere
south_wnd = southern_hemi_df["Wind Speed"]
south_lat = southern_hemi_df["Lat"]
plt.scatter(south_lat, south_wnd, marker = "o", facecolors = "purple")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Linear Regression of The Wind Speed in Southern Hemisphere Cities")
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_lat,south_wnd)
reg_sw = south_lat * slope + intercept
leq_sw = "y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))
plt.plot(south_lat, reg_sw, "r-")
plt.annotate(leq_sc, (-50,12), fontsize = 17, color = "red")
# Printing the r-value comment
print(f"The r-value is: {round(rvalue,4)}")
# Out:
# The r-value is: -0.3471

# %% [markdown]
# **Discussion about the linear relationship:** In the northern hemisphere, there is essentially no correlation between wind speed and latitude, the r-value of 0.0573 states as such. However in the southern hemisphere, there is a slightly negative correlation between latitude and windspeed, indicating that as the latitude approaches 0, wind speed decreases.
